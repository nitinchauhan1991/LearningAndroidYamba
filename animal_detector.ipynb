# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinchauhan1991/LearningAndroidYamba/blob/master/animal_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YBxTwfx6h0eHjTprrycz")
project = rf.workspace("myproject-zxfbp").project("monkey-cat-dog-xkxci")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.9/175.9 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 131.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to monkey,cat,dog-1 in yolov8:: 100%|██████████| 942/942 [00:00<00:00, 7595.72it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load nano model (lightest, best for RPi)
model = YOLO("yolov8n.pt")

model.train(
    data="/content/animal_detect/data.yaml",
    epochs=50,
    imgsz=320,        # keep 320 for RPi performance
    batch=16,
    name="animal_detector",
    patience=10,      # stops early if no improvement
    device="cuda"     # uses GPU on Colab
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# Check accuracy before exporting
metrics = model.val()

print(f"mAP50: {metrics.box.map50:.2f}")
print(f"mAP50-95: {metrics.box.map:.2f}")
# Out:
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1417.8±599.5 MB/s, size: 53.6 KB)
# val: Scanning /content/animal_detect/valid/labels.cache... 92 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 92/92 27.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.1it/s 1.5s
#                    all         92        267      0.842      0.725      0.823      0.515
#                    cat         45         89      0.815      0.594      0.718      0.438
#                    dog         33         56      0.832      0.796      0.872      0.605
#                 monkey         34        122       0.88      0.787      0.879      0.501
# Speed: 1.6ms preprocess, 3.2ms inference, 0.0ms loss, 5.3ms postprocess per image
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load your trained best weights
model = YOLO("runs/detect/animal_detector/weights/best.pt")

# Export to NCNN
model.export(
    format="ncnn",
    imgsz=320,        # must match training size
    half=False        # keep False for RPi5 (no GPU half precision)
)
# Out:
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ NCNN export does not support end2end models, disabling end2end branch.
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs/detect/animal_detector/weights/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 7, 2100) (5.9 MB)
#
# NCNN: starting export with NCNN 1.0.20260114 and PNNX 20260409...
# NCNN: export success ✅ 4.3s, saved as 'runs/detect/animal_detector/weights/best_ncnn_model' (11.6 MB)
#
# Export complete (4.6s)
# Results saved to /content/runs/detect/animal_detector/weights
# Predict:         yolo predict task=detect model=runs/detect/animal_detector/weights/best_ncnn_model imgsz=320
# Validate:        yolo val task=detect model=runs/detect/animal_detector/weights/best_ncnn_model imgsz=320 data=/content/animal_detect/data.yaml
# Visualize:       https://netron.app
# ...

# %%
import shutil
from google.colab import files

# Zip the ncnn model folder
shutil.make_archive("animal_ncnn_model", "zip", "runs/detect/animal_detector/weights/best_ncnn_model")

# Download to your PC
files.download("animal_ncnn_model.zip")
